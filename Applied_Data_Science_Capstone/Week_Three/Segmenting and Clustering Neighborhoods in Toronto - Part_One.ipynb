# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto I

# %% [markdown]
# ### For this assignment, you will be required to explore and cluster the neighborhoods in Toronto.
#
# 1. Start by creating a new Notebook for this assignment.
# 2. Hints for scraping Notebook
# 3. To create the above dataframe:
#     - The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
#     - Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
#     - More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11  in the above table.
#     - If a cell has a borough but a Not assigned  neighborhood, then the neighborhood will be the same as the borough.
#     - Clean your Notebook and add Markdown cells to explain your work and any assumptions you are making.
#     - In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %% [markdown]
# ## Start!

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import requests
import lxml.html as lh
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Get Toronto Post Code Info from: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source, 'lxml')

table = soup.find("table")
table_rows = table.tbody.find_all("tr")

PostCode = []
Borough = []
Neighborhood = []
temp = []
for tr in table_rows:
    td = tr.find_all("td")
    for row in td:
        postal_code = row.find('p').contents[0]
        r = row.find('span').contents[0]
        if r != 'Not assigned':   # valid info
            # postal code append
            PostCode.append(postal_code)
            # borough with href
            if row.find('span').find('a'):
                Borough.append(row.find('span').find('a').contents[0])
            # borough without href
            else:
                Borough.append(r)
            
            for i in row.find_all('a'):
                if i.get_text() in Borough:
                    Neighborhood.append(', '.join(temp))
                    temp = []
                else:
                    temp.append(i.get_text())

Neighborhood = Neighborhood[1:]
Neighborhood[4] = 'Ontario Provincial Government'
Neighborhood[10] = 'Glencairn'
Neighborhood[11] = 'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale'
Neighborhood[17] = 'Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood'
Neighborhood[19] = 'The Beaches'
Neighborhood[20] = 'Berczy Park'
Neighborhood[25] = 'Christie'
Neighborhood[30] = 'Richmond, Adelaide, King'
Neighborhood[33] = 'Fairview, Henry Farm, Oriole'
Neighborhood[37] = 'Little Portugal, Trinity'
Neighborhood[41] = 'The Danforth West, Riverdale'
Neighborhood[43] = 'Brockton, Parkdale Village, Exhibition Place'
Neighborhood[45] = 'York Mills, Silver Hills'
Neighborhood[47] = 'India Bazaar, The Beaches West'
del Neighborhood[48:49]
Neighborhood[49] = 'North Park, Maple Leaf Park, Upwood Park'
Neighborhood[52] = 'Willowdale, Newtonbrook'
Neighborhood.insert(54, 'Studio District')
Neighborhood[56] = 'Del Ray, Mount Dennis, Keelsdale and Silverthorn'
Neighborhood.insert(61, 'Lawrence Park')
Neighborhood[62] = 'Roselawn'
Neighborhood[67] = 'Davisville North'
Neighborhood[68] = 'Forest Hill North & West'
Neighborhood[69] = 'The Junction South'
Neighborhood[70] = 'Westmount'
Neighborhood[73] = 'North Toronto West'
Neighborhood[74] = 'The Annex, North Midtown, Yorkville'
Neighborhood[75] = 'Parkdale, Roncesvalles'
Neighborhood[76] = 'Canada Post Gateway Processing Centre (Enclave of L4W)'
Neighborhood[77] = 'Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens'
Neighborhood[79] = 'Davisville'
Neighborhood[80] = 'University of Toronto, Harbord'
Neighborhood[81] = 'Runnymede, Swansea'
Neighborhood[82] = "Clarks Corners, Tam O'Shanter, Sullivan"
Neighborhood[83] = 'Moore Park, Summerhill East'
Neighborhood[86] = "Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park"
del Neighborhood[87:88]
Neighborhood[87] = "CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport"
Neighborhood[88] = "New Toronto, Mimico South, Humber Bay Shores"
Neighborhood[89] = "South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens"
Neighborhood[92] = "Stn A PO Boxes 25 The Esplanade (Enclave of M5E)"
Neighborhood[94] = "Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale"
Neighborhood[98] = "The Kingsway, Montgomery Road, Old Mill North"
Neighborhood[100] = "Business reply mail Processing Centre 969 Eastern (Enclave of M4L)"
Neighborhood.append('Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West')

# print(PostCode)
# print((Neighborhood))
# print(len(Neighborhood))   103
# print(len(PostCode))  103
# print(len(Borough))   103
res = {'PostalCode': PostCode, 'Borough': Borough, 'Neighborhood': Neighborhood}
df = pd.DataFrame(res)
df
# Out:
# ['M3A', 'M4A', 'M5A', 'M6A', 'M7A', 'M9A', 'M1B', 'M3B', 'M4B', 'M5B', 'M6B', 'M9B', 'M1C', 'M3C', 'M4C', 'M5C', 'M6C', 'M9C', 'M1E', 'M4E', 'M5E', 'M6E', 'M1G', 'M4G', 'M5G', 'M6G', 'M1H', 'M2H', 'M3H', 'M4H', 'M5H', 'M6H', 'M1J', 'M2J', 'M3J', 'M4J', 'M5J', 'M6J', 'M1K', 'M2K', 'M3K', 'M4K', 'M5K', 'M6K', 'M1L', 'M2L', 'M3L', 'M4L', 'M5L', 'M6L', 'M9L', 'M1M', 'M2M', 'M3M', 'M4M', 'M5M', 'M6M', 'M9M', 'M1N', 'M2N', 'M3N', 'M4N', 'M5N', 'M6N', 'M9N', 'M1P', 'M2P', 'M4P', 'M5P', 'M6P', 'M9P', 'M1R', 'M2R', 'M4R', 'M5R', 'M6R', 'M7R', 'M9R', 'M1S', 'M4S', 'M5S', 'M6S', 'M1T', 'M4T', 'M5T', 'M1V', 'M4V', 'M5V', 'M8V', 'M9V', 'M1W', 'M4W', 'M5W', 'M8W', 'M9W', 'M1X', 'M4X', 'M5X', 'M8X', 'M4Y', 'M7Y', 'M8Y', 'M8Z']
# ['Parkwoods', 'Victoria Village', 'Regent Park, Harbourfront', 'Lawrence Manor, Lawrence Heights', 'Ontario Provincial Government', 'Islington Avenue', 'Malvern, Rouge', 'Don Mills', 'Parkview Hill, Woodbine Gardens', 'Garden District, Ryerson', 'Glencairn', 'West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale', 'Rouge Hill, Port Union, Highland Creek', 'Don Mills, Flemingdon Park', 'Woodbine Heights', 'St. James Town', 'Humewood-Cedarvale', 'Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood', 'Guildwood, Morningside, West Hill', 'The Beaches', 'Berczy Park', 'Caledonia-Fairbanks', 'Woburn', 'Leaside', 'Bay Street', 'Christie', 'Cedarbrae', 'Hillcrest Village', 'Bathurst Manor, Wilson Heights, Downsview', 'Thorncliffe Park', 'Richmond, Adelaide, King', 'Dovercourt Village', 'Scarborough Village', 'Fairview, Henry Farm, Oriole', 'Northwood Park, York University', 'The Danforth', 'Harbourfront, Union Station, Toronto Islands', 'Little Portugal, Trinity', 'Kennedy Park, Ionview, Birchmount Park', 'Bayview Village', 'Downsview, CFB Toronto', 'The Danforth West, Riverdale', 'Toronto Dominion Centre, Design Exchange', 'Brockton, Parkdale Village, Exhibition Place', 'Golden Mile, Clairlea, Oakridge', 'York Mills, Silver Hills', 'Downsview', 'India Bazaar, The Beaches West', 'Commerce Court, Victoria Hotel', 'North Park, Maple Leaf Park, Upwood Park', 'Humber Summit', 'Cliffside, Cliffcrest, Scarborough Village', 'Willowdale, Newtonbrook', 'Downsview', 'Studio District', 'Bedford Park, Lawrence Manor', 'Del Ray, Mount Dennis, Keelsdale and Silverthorn', 'Humberlea, Emery', 'Birch Cliff, Cliffside', 'Willowdale', 'Downsview', 'Lawrence Park', 'Roselawn', 'Runnymede, The Junction', 'Weston', 'Dorset Park, Wexford Heights, Scarborough Town Centre', 'York Mills', 'Davisville North', 'Forest Hill North & West', 'The Junction South', 'Westmount', 'Wexford, Maryvale', 'Willowdale', 'North Toronto West', 'The Annex, North Midtown, Yorkville', 'Parkdale, Roncesvalles', 'Canada Post Gateway Processing Centre (Enclave of L4W)', 'Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens', 'Agincourt', 'Davisville', 'University of Toronto, Harbord', 'Runnymede, Swansea', "Clarks Corners, Tam O'Shanter, Sullivan", 'Moore Park, Summerhill East', 'Kensington Market, Chinatown, Grange Park', "Milliken, Agincourt North, Steeles, L'Amoreaux", 'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park', 'CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport', 'New Toronto, Mimico South, Humber Bay Shores', 'South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens', "Steeles, L'Amoreaux", 'Rosedale', 'Stn A PO Boxes 25 The Esplanade (Enclave of M5E)', 'Alderwood, Long Branch', 'Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale', 'Upper Rouge', 'St. James Town, Cabbagetown', 'First Canadian Place, Underground city', 'The Kingsway, Montgomery Road, Old Mill North', 'Church and Wellesley', 'Business reply mail Processing Centre 969 Eastern (Enclave of M4L)', 'Old Mill, Sunnylea, Humber Bay, Mimico, The Queensway', 'Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West']
# 103
#     PostalCode              Borough  \
# 0          M3A           North York
# 1          M4A           North York
# 2          M5A     Downtown Toronto
# 3          M6A           North York
# 4          M7A         Queen's Park
# ..         ...                  ...
# 98         M8X            Etobicoke
# 99         M4Y     Downtown Toronto
# 100        M7Y  Business reply mail
# 101        M8Y            Etobicoke
# 102        M8Z            Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4                        Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre 969 East...
# 101  Old Mill, Sunnylea, Humber Bay, Mimico, The Qu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]
