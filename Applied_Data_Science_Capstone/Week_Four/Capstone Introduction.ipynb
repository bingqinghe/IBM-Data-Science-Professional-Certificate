# %% [markdown]
# # The Battle of Neighborhoods

# %% [markdown]
# ## Introduction

# %% [markdown]
# As one of the world's most important global cities, London is the capital and largest city of England and the United Kingdom. It exerts considerable influence upon the arts, commerce, education, entertainment, fashion, finance, healthcare, media, professional services, research and development, tourism and transportation. It is one of the largest financial centres in the world and in 2019, London had the second highest number of ultra high-net-worth individuals in Europe, after Paris. London has a diverse range of people and cultures, and more than 300 languages are spoken in the region. Its estimated mid-2018 municipal population (corresponding to Greater London) was roughly 9 million, which made it the third-most populous city in Europe. London accounts for 13.4% of the U.K. population.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# Out client has an interest in investing a restaurant in London. They approached us to research the market and provide a suggestion of the location and the type of restaurant in one of the neighbourhoods which would have the most interest. The main objective of this project is to extract and analyse the right data about various neighbourhoods of London using various data science techniques and suggest our client a suitable location and type for their restaurant.

# %% [markdown]
# ## Data

# %% [markdown]
# #### The following data are used:
# 1. Neighbourhoods of London
# 2. Geographical coordinates of the neighbourhoods
# 3. Venues data around the neighbourhoods from FourSquare

# %% [markdown]
# #### Neighbourhoods

# %% [markdown]
# - Data is extracted from the "List of areas of London" Wikipedia page with URL: https://en.wikipedia.org/wiki/List_of_areas_of_London
# - Python BeautifulSoup library is used for web scraping
# - Detailed list of neighbourhoods in Lodon

# %% [markdown]
# #### Geographical Coordinates

# %% [markdown]
# - Python GeoPy library is used for extracting the geographical coordinates of various neighbourhoods
# - Used for visualizing the data by plotting maps

# %% [markdown]
# #### Venue Data

# %% [markdown]
# - FourSquare API is used for extracting data
# - Used fro studying venues in various neighbourhoods
# - Data provides the restaurant information in the area and used for drawing the conclusion
